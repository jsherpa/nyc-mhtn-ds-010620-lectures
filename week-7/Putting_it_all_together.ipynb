# %%
import pandas as pd
pd.set_option('display.max_columns', 300)
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from scipy.stats import shapiro
from scipy.stats import normaltest
from sklearn.preprocessing import StandardScaler, RobustScaler
import seaborn as sns
sns.set(style="whitegrid")

# %% [markdown]
# # Putting it all together

# %%
df = pd.read_csv('feature_selection/resources/cleaned_movie_data.csv', index_col=0)

# %%
sns.heatmap(df.isnull(), cbar=False)

# %%
CRISP DM

# %%
df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4154.000000  4155.000000               4156.00000
# mean               159.384208   109.561492                747.16001
# std                122.582072    22.667591               2946.34955
# min                  1.000000    34.000000                  0.00000
# 25%                 70.000000    95.000000                 10.00000
# 50%                130.000000   105.000000                 57.00000
# 75%                217.000000   119.000000                218.00000
# max                813.000000   334.000000              23000.00000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4144.000000             4153.000000  4.157000e+03
# mean               724.113176             7347.613051  4.849151e+07
# std               1811.189057            15053.307332  6.846135e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                172.750000              699.000000  5.354039e+06
# 50%                416.000000             1000.000000  2.552850e+07
# 75%                676.000000            12000.000000  6.231888e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     4.157000e+03                4157.000000           4150.000000
# mean      9.752737e+04               10887.253067              1.374217
# std       1.472840e+05               18520.203794              2.041144
# min       5.000000e+00                   0.000000              0.000000
# 25%       1.516900e+04                1739.000000              0.000000
# 50%       4.641700e+04                3698.000000              1.000000
# 75%       1.146100e+05               15569.000000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           4156.000000  4.157000e+03  4156.000000
# mean             312.961742  4.491703e+07  2003.267565
# std              399.514498  2.151887e+08     9.945465
# min                1.000000  2.180000e+02  1920.000000
# 25%               93.000000  1.000000e+07  1999.000000
# 50%              190.000000  2.500000e+07  2005.000000
# 75%              374.000000  5.091162e+07  2010.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  movie_facebook_likes            G  \
# count             4151.000000  4157.000000           4157.000000  4157.000000
# mean              1888.954710     6.468631           8734.818138     0.022853
# std               4371.346743     1.050852          20792.379704     0.149453
# min                  0.000000     1.600000              0.000000     0.000000
# 25%                343.500000     5.900000              0.000000     0.000000
# 50%                650.000000     6.600000            183.000000     0.000000
# 75%                962.000000     7.200000          10000.000000     0.000000
# max             137000.000000     9.300000         349000.000000     1.000000
#
#              Other           PG        PG-13            R
# count  4157.000000  4157.000000  4157.000000  4157.000000
# mean      0.046909     0.146981     0.336781     0.446476
# std       0.211469     0.354130     0.472666     0.497187
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     1.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000

# %%
df.shape
# Out:
# (4157, 32)

# %%
df.boxplot('gross')

# %%
df.boxplot('budget')

# %%
df = df[df['budget']<400000000]

# %%
df.shape
# Out:
# (4145, 32)

# %% [markdown]
# ## Data Cleaning:
# - Removing outliers
#
# - Handling missing values
#     - drop observation
#     - impute the missing value using mean, median or mode
#     - impute the missing data based on the value in other column(take mean of different groups)
#     - estimate the missing value based on the other columns(linear regression)
# - Make messy data value consistent ('SEAN' == 'sean' == 'Sean')
# - proper and consistent data types. ('3' vs. 3)
# - remove duplicates
# - Numeric vs cat

# %% [markdown]
# ## EDA
# - Look at the distribution of the variables. For both features and target
#   - plots
# - Measure the corrlealtion between features.
# - check if Categorical data is ordinal.
# - check linear relationships with target variable.
# - Knowing the sample statistics of the target and features.
# - perform statistical test to determine relationships between features and target.

# %% [markdown]
# ## Feature Engineering
# - Create interactions
# - create polynomial features
# - non-linear transformation of traget or features (log, sqrt, reciprocal)
# - create dummy variable for categorical data
# - combining multiple variables into one( ratio, index)
# - Geo-spacial Transformation (distance from point of interest, located within boundaries)
# - Time transformation and aggregration( year born --> years old, day of week, isholiday() )
# - scaling data

# %% [markdown]
# ## Feature Selection
# - Filter Method:
#     - Multi-colinearity
#     - select K-best
# - Wrapper Method:
#     - Recurrsive Feature Elimination
#     - step-wise selection
# - Embedded Method:
#     - Lasso
#     - feature importance

# %% [markdown]
# ## Model Selection
# - Cross Validation
# - Test Train Split
# - Grid Search

# %%
sns.jointplot(x='budget', y='gross', data=df, kind="reg")

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(df[['budget']])
df['budget_scaled']= scaled

# %%
sns.jointplot(x='budget_scaled', y='gross', data=df, kind="reg")

# %%
robust_scaler = RobustScaler()
scaled = robust_scaler.fit_transform(df[['budget']])
df['budget_robust']= scaled

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 5                   640.0   73058679.0          Action|Adventure|Sci-Fi
#
#       actor_1_name                                movie_title  \
# 0      CCH Pounder                                    Avatar
# 1      Johnny Depp  Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                   Spectre
# 3        Tom Hardy                     The Dark Knight Rises
# 5     Daryl Sabara                               John Carter
#
#    num_voted_users  cast_total_facebook_likes          actor_3_name  \
# 0           886204                       4834             Wes Studi
# 1           471220                      48350        Jack Davenport
# 2           275868                      11700      Stephanie Sigman
# 3          1144337                     106759  Joseph Gordon-Levitt
# 5           212204                       1873          Polly Walker
#
#    facenumber_in_poster                                    movie_imdb_link  \
# 0                   0.0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...
# 1                   0.0  http://www.imdb.com/title/tt0449088/?ref_=fn_t...
# 2                   1.0  http://www.imdb.com/title/tt2379713/?ref_=fn_t...
# 3                   0.0  http://www.imdb.com/title/tt1345836/?ref_=fn_t...
# 5                   1.0  http://www.imdb.com/title/tt0401729/?ref_=fn_t...
#
#    num_user_for_reviews language country content_rating       budget  \
# 0                3054.0  English     USA          PG-13  237000000.0
# 1                1238.0  English     USA          PG-13  300000000.0
# 2                 994.0  English      UK          PG-13  245000000.0
# 3                2701.0  English     USA          PG-13  250000000.0
# 5                 738.0  English     USA          PG-13  263700000.0
#
#    title_year  actor_2_facebook_likes  imdb_score  movie_facebook_likes  \
# 0      2009.0                   936.0         7.9                 33000
# 1      2007.0                  5000.0         7.1                     0
# 2      2015.0                   393.0         6.8                 85000
# 3      2012.0                 23000.0         8.5                164000
# 5      2012.0                   632.0         6.6                 24000
#
#   rating  G  Other  PG  PG-13  R  budget_scaled  budget_robust
# 0  PG-13  0      0   0      1  0       4.710680         5.3000
# 1  PG-13  0      0   0      1  0       6.203291         6.8750
# 2  PG-13  0      0   0      1  0       4.900218         5.5000
# 3  PG-13  0      0   0      1  0       5.018679         5.6250
# 5  PG-13  0      0   0      1  0       5.343263         5.9675

# %%
sns.jointplot(x='budget_robust', y='gross', data=df, kind="reg")

# %%
lm = linear_model.LinearRegression()
lm.fit(df[['budget']], df['gross'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
def checkresiduals(df, feature, target, sm_model):
    # checking for our model - Homoscedasticity,  Independence of residuals
    pred_val = sm_model.predict(df[[feature]])
    true_val = df[target].values.copy()
    residual = true_val - pred_val

    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
#     fig, ax = plt.subplots(figsize=(8, 6))
    ax1.hist(residual, density=True, bins=30)
    ax2.scatter(df[target],residual)
    ax2.set_title('Residual Scatterplot')
    plt.show()
    stat, p = shapiro(residual)
#     stat, p = normaltest(data)

    print('Statistics=%.3f, p=%.3f' % (stat, p))
    # interpret
    alpha = 0.05
    if p > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
    else:
        print('Sample does not look Gaussian (reject H0)')

# %%
checkresiduals(df, 'budget', 'gross', lm)
# Out:
# Statistics=0.796, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
df['gross_log'] = np.log(df['gross'])
df['gross_sqrt'] = np.sqrt(df['gross'])

# %%
lm = linear_model.LinearRegression()
lm.fit(df[['budget']], df['gross_log'])
checkresiduals(df, 'budget', 'gross_log', lm)
# Out:
# Statistics=0.880, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
lm = linear_model.LinearRegression()
lm.fit(df[['budget']], df['gross_sqrt'])
checkresiduals(df, 'budget', 'gross_sqrt', lm)
# Out:
# Statistics=0.969, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
df['budget_log'] = np.log(df['budget'])
df['budget_sqrt'] = np.sqrt(df['budget'])

# %%
lm = linear_model.LinearRegression()
lm.fit(df[['budget_sqrt']], df['gross'])
checkresiduals(df, 'budget_sqrt', 'gross', lm)
# Out:
# Statistics=0.813, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
lm = linear_model.LinearRegression()
lm.fit(df[['budget_sqrt']], df['gross_sqrt'])
checkresiduals(df, 'budget_sqrt', 'gross_sqrt', lm)
# Out:
# Statistics=0.977, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
sns.jointplot(x='budget_log', y='gross_sqrt', data=df, kind="reg")

# %%
lm = linear_model.LinearRegression()
lm.fit(df[['budget_log']], df['gross_sqrt'])
checkresiduals(df, 'budget_log', 'gross_sqrt', lm)
# Out:
# Statistics=0.102, p=0.950
# Sample looks Gaussian (fail to reject H0)

# %%
sns.jointplot(x='budget_log', y='gross_log', data=df, kind="reg")

# %%
lm = linear_model.LinearRegression()
lm.fit(df[['budget_log']], df['gross_log'])
checkresiduals(df, 'budget_log', 'gross_log', lm)
# Out:
# Statistics=0.102, p=0.950
# Sample looks Gaussian (fail to reject H0)

# %% [markdown]
# https://machinelearningmastery.com/a-gentle-introduction-to-normality-tests-in-python/
