# %% [markdown]
# ## Imports

# %%
import pandas as pd
pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows', 300)
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import Lasso, Ridge, LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from scipy.stats import shapiro
from scipy.stats import normaltest
from sklearn.preprocessing import StandardScaler, RobustScaler
import seaborn as sns
from statsmodels.formula.api import ols
import statsmodels.api as sm
import datetime
sns.set(style="whitegrid")

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }

# %%
df = pd.read_csv('pek-sha.csv')

# %%
df
# Out:
#               ID flightNumber craftTypeCode depAirport traAirport arrAirport  \
# 0          14393       HO1252           320        PEK        NaN        SHA
# 1          14409       MU5138           33L        PEK        NaN        SHA
# 2          14415       MU5138           33L        PEK        NaN        SHA
# 3          14429       HU7605           350        PEK        NaN        SHA
# 4          14431       HU7605           350        PEK        NaN        SHA
# ...          ...          ...           ...        ...        ...        ...
# 300331  80162962       MU5390           325        PEK        LYA        SHA
# 300332  80162963       MU5390           325        PEK        LYA        SHA
# 300333  80162964       MU5390           325        PEK        LYA        SHA
# 300334  80162965       MU5390           325        PEK        LYA        SHA
# 300335  80162967       MU5390           325        PEK        LYA        SHA
#
#               departureDate          arrivalDate cabinClass priceClass  price  \
# 0       2019-01-04 06:35:00  2019-01-04 08:55:00          C          C   1860
# 1       2019-01-04 07:00:00  2019-01-04 09:15:00          C          I   1640
# 2       2019-01-04 07:00:00  2019-01-04 09:15:00          C          J   5360
# 3       2019-01-04 07:20:00  2019-01-04 09:35:00          C          I   1635
# 4       2019-01-04 07:20:00  2019-01-04 09:35:00          C          I   1640
# ...                     ...                  ...        ...        ...    ...
# 300331  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          R    830
# 300332  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          R    880
# 300333  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          R    920
# 300334  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          R    810
# 300335  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          Y   1490
#
#         rate           createDate  dateDifference
# 0       1.00  2019-01-03 14:26:15               1
# 1       0.31  2019-01-03 14:26:15               1
# 2       1.00  2019-01-03 14:26:15               1
# 3       0.29  2019-01-03 14:26:15               1
# 4       0.29  2019-01-03 14:26:15               1
# ...      ...                  ...             ...
# 300331  0.56  2019-07-23 05:58:47               7
# 300332  0.60  2019-07-23 05:58:47               7
# 300333  0.62  2019-07-23 05:58:47               7
# 300334  0.55  2019-07-23 05:58:47               7
# 300335  1.00  2019-07-23 05:58:47               7
#
# [300336 rows x 14 columns]

# %% [markdown]
# ## data cleaning

# %%
df.head()
# Out:
#       ID flightNumber craftTypeCode depAirport traAirport arrAirport  \
# 0  14393       HO1252           320        PEK        NaN        SHA
# 1  14409       MU5138           33L        PEK        NaN        SHA
# 2  14415       MU5138           33L        PEK        NaN        SHA
# 3  14429       HU7605           350        PEK        NaN        SHA
# 4  14431       HU7605           350        PEK        NaN        SHA
#
#          departureDate          arrivalDate cabinClass priceClass  price  \
# 0  2019-01-04 06:35:00  2019-01-04 08:55:00          C          C   1860
# 1  2019-01-04 07:00:00  2019-01-04 09:15:00          C          I   1640
# 2  2019-01-04 07:00:00  2019-01-04 09:15:00          C          J   5360
# 3  2019-01-04 07:20:00  2019-01-04 09:35:00          C          I   1635
# 4  2019-01-04 07:20:00  2019-01-04 09:35:00          C          I   1640
#
#    rate           createDate  dateDifference
# 0  1.00  2019-01-03 14:26:15               1
# 1  0.31  2019-01-03 14:26:15               1
# 2  1.00  2019-01-03 14:26:15               1
# 3  0.29  2019-01-03 14:26:15               1
# 4  0.29  2019-01-03 14:26:15               1

# %%
## fill Nan's with 0 in the transit column 

df.traAirport.fillna(0, inplace = True)

# %%
df.traAirport.replace('LYA',1, inplace = True)

# %%
sns.heatmap(df.isnull(), cbar=False)

# %%
## , kind="reg"
sns.scatterplot(x='priceClass', y='price', data=df)

# %%
df['price_Class'].sort_values()

# %%
df['TOD']= [x[11:16] for x in df.departureDate]

# %%
df['TOD'] = pd.to_datetime(df['TOD'])

# %%
df['TOD'] = [time.time() for time in df['TOD']]

# %%
df['TODD']= np.where(((df['TOD']> datetime.time(6,0)) & (df['TOD']<= datetime.time(12,0))), 'M', np.nan)

# %%
df['TODD'] = np.where(((df['TOD']> datetime.time(12,0)) & (df['TOD']<= datetime.time(18,0))), 'A', df['TODD'])

# %%
df['TODD'] = np.where(((df['TOD']> datetime.time(18,0)) & (df['TOD']<= datetime.time(23,0))), 'N', df['TODD'])

# %%
df
# Out:
#               ID flightNumber craftTypeCode depAirport  traAirport arrAirport  \
# 0          14393       HO1252           320        PEK           0        SHA
# 1          14409       MU5138           33L        PEK           0        SHA
# 2          14415       MU5138           33L        PEK           0        SHA
# 3          14429       HU7605           350        PEK           0        SHA
# 4          14431       HU7605           350        PEK           0        SHA
# ...          ...          ...           ...        ...         ...        ...
# 300331  80162962       MU5390           325        PEK           1        SHA
# 300332  80162963       MU5390           325        PEK           1        SHA
# 300333  80162964       MU5390           325        PEK           1        SHA
# 300334  80162965       MU5390           325        PEK           1        SHA
# 300335  80162967       MU5390           325        PEK           1        SHA
#
#               departureDate          arrivalDate cabinClass priceClass  price  \
# 0       2019-01-04 06:35:00  2019-01-04 08:55:00          C          C   1860
# 1       2019-01-04 07:00:00  2019-01-04 09:15:00          C          I   1640
# 2       2019-01-04 07:00:00  2019-01-04 09:15:00          C          J   5360
# 3       2019-01-04 07:20:00  2019-01-04 09:35:00          C          I   1635
# 4       2019-01-04 07:20:00  2019-01-04 09:35:00          C          I   1640
# ...                     ...                  ...        ...        ...    ...
# 300331  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          R    830
# 300332  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          R    880
# 300333  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          R    920
# 300334  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          R    810
# 300335  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          Y   1490
#
#         rate           createDate  dateDifference       TOD TODD
# 0       1.00  2019-01-03 14:26:15               1  06:35:00    M
# 1       0.31  2019-01-03 14:26:15               1  07:00:00    M
# 2       1.00  2019-01-03 14:26:15               1  07:00:00    M
# 3       0.29  2019-01-03 14:26:15               1  07:20:00    M
# 4       0.29  2019-01-03 14:26:15               1  07:20:00    M
# ...      ...                  ...             ...       ...  ...
# 300331  0.56  2019-07-23 05:58:47               7  13:10:00    A
# 300332  0.60  2019-07-23 05:58:47               7  13:10:00    A
# 300333  0.62  2019-07-23 05:58:47               7  13:10:00    A
# 300334  0.55  2019-07-23 05:58:47               7  13:10:00    A
# 300335  1.00  2019-07-23 05:58:47               7  13:10:00    A
#
# [300336 rows x 16 columns]

# %%
sns.barplot(x = df['TODD'], y = df['price'], data= df)

# %%
## Get the 
df['DD']= [x[:10] for x in df.departureDate]

# %%
df['DD']
# Out:
# 0         2019-01-04
# 1         2019-01-04
# 2         2019-01-04
# 3         2019-01-04
# 4         2019-01-04
#              ...
# 300331    2019-07-30
# 300332    2019-07-30
# 300333    2019-07-30
# 300334    2019-07-30
# 300335    2019-07-30
# Name: DD, Length: 300336, dtype: object

# %%
sns.barplot(x = df['Month'], y = df['price'], data= df)

# %%
import calendar

# %%
def findDay(date):
    born = datetime.datetime.strptime(date, '%Y-%m-%d').weekday()
    return (calendar.day_name[born])

# %%
df['DOW'] = [findDay(x) for x in df['DD']]

# %%
df
# Out:
#               ID flightNumber craftTypeCode depAirport  traAirport arrAirport  \
# 0          14393       HO1252           320        PEK           0        SHA
# 1          14409       MU5138           33L        PEK           0        SHA
# 2          14415       MU5138           33L        PEK           0        SHA
# 3          14429       HU7605           350        PEK           0        SHA
# 4          14431       HU7605           350        PEK           0        SHA
# ...          ...          ...           ...        ...         ...        ...
# 300331  80162962       MU5390           325        PEK           1        SHA
# 300332  80162963       MU5390           325        PEK           1        SHA
# 300333  80162964       MU5390           325        PEK           1        SHA
# 300334  80162965       MU5390           325        PEK           1        SHA
# 300335  80162967       MU5390           325        PEK           1        SHA
#
#               departureDate          arrivalDate cabinClass priceClass  price  \
# 0       2019-01-04 06:35:00  2019-01-04 08:55:00          C          C   1860
# 1       2019-01-04 07:00:00  2019-01-04 09:15:00          C          I   1640
# 2       2019-01-04 07:00:00  2019-01-04 09:15:00          C          J   5360
# 3       2019-01-04 07:20:00  2019-01-04 09:35:00          C          I   1635
# 4       2019-01-04 07:20:00  2019-01-04 09:35:00          C          I   1640
# ...                     ...                  ...        ...        ...    ...
# 300331  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          R    830
# 300332  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          R    880
# 300333  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          R    920
# 300334  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          R    810
# 300335  2019-07-30 13:10:00  2019-07-30 18:10:00          Y          Y   1490
#
#         rate           createDate  dateDifference       TOD TODD          DD  \
# 0       1.00  2019-01-03 14:26:15               1  06:35:00    M  2019-01-04
# 1       0.31  2019-01-03 14:26:15               1  07:00:00    M  2019-01-04
# 2       1.00  2019-01-03 14:26:15               1  07:00:00    M  2019-01-04
# 3       0.29  2019-01-03 14:26:15               1  07:20:00    M  2019-01-04
# 4       0.29  2019-01-03 14:26:15               1  07:20:00    M  2019-01-04
# ...      ...                  ...             ...       ...  ...         ...
# 300331  0.56  2019-07-23 05:58:47               7  13:10:00    A  2019-07-30
# 300332  0.60  2019-07-23 05:58:47               7  13:10:00    A  2019-07-30
# 300333  0.62  2019-07-23 05:58:47               7  13:10:00    A  2019-07-30
# 300334  0.55  2019-07-23 05:58:47               7  13:10:00    A  2019-07-30
# 300335  1.00  2019-07-23 05:58:47               7  13:10:00    A  2019-07-30
#
#        Month      DOW
# 0         20   Friday
# 1         20   Friday
# 2         20   Friday
# 3         20   Friday
# 4         20   Friday
# ...      ...      ...
# 300331    20  Tuesday
# 300332    20  Tuesday
# 300333    20  Tuesday
# 300334    20  Tuesday
# 300335    20  Tuesday
#
# [300336 rows x 19 columns]

# %%
sns.barplot(x = df['DOW'], y = df['price'], data= df)

# %%
df['DOW'].value_counts()

# %%
df['US_Price'] = [x * 0.14 for x in df['price']]

# %%
df.drop(['craftTypeCode', 'departureDate', 'arrivalDate'], axis =1, inplace = True)

# %%
df['DOPD'] = [x[:10] for x in df['createDate']]

# %%
df['PD'] = [x[:10] for x in df['createDate']]

# %%
df['DOPD'] = [findDay(x) for x in df['DOPD']]

# %%
df['MOPD'] = [x[5:7] for x in df['PD']]

# %%
df['TOPD'] = [x[11:16] for x in df['createDate']]

# %%
df['TOPD'] = pd.to_datetime(df['TOPD'])

# %%
df['TOPD'] = [time.time() for time in df['TOPD']]

# %%
df['TOPD_L']= np.where(((df['TOPD']> datetime.time(6,0)) & (df['TOPD']<= datetime.time(12,0))), 'M', np.nan)
df['TOPD_L'] = np.where(((df['TOPD']> datetime.time(12,0)) & (df['TOPD']<= datetime.time(18,0))), 'A', df['TOPD_L'])
df['TOPD_L'] = np.where(((df['TOPD']> datetime.time(18,0)) & (df['TOPD']<= datetime.time(23,0))), 'N', df['TOPD_L'])

# %%
df
# Out:
#               ID flightNumber depAirport  traAirport arrAirport cabinClass  \
# 0          14393       HO1252        PEK           0        SHA          C
# 1          14409       MU5138        PEK           0        SHA          C
# 2          14415       MU5138        PEK           0        SHA          C
# 3          14429       HU7605        PEK           0        SHA          C
# 4          14431       HU7605        PEK           0        SHA          C
# ...          ...          ...        ...         ...        ...        ...
# 300331  80162962       MU5390        PEK           1        SHA          Y
# 300332  80162963       MU5390        PEK           1        SHA          Y
# 300333  80162964       MU5390        PEK           1        SHA          Y
# 300334  80162965       MU5390        PEK           1        SHA          Y
# 300335  80162967       MU5390        PEK           1        SHA          Y
#
#        priceClass  price  rate           createDate  dateDifference       TOD  \
# 0               C   1860  1.00  2019-01-03 14:26:15               1  06:35:00
# 1               I   1640  0.31  2019-01-03 14:26:15               1  07:00:00
# 2               J   5360  1.00  2019-01-03 14:26:15               1  07:00:00
# 3               I   1635  0.29  2019-01-03 14:26:15               1  07:20:00
# 4               I   1640  0.29  2019-01-03 14:26:15               1  07:20:00
# ...           ...    ...   ...                  ...             ...       ...
# 300331          R    830  0.56  2019-07-23 05:58:47               7  13:10:00
# 300332          R    880  0.60  2019-07-23 05:58:47               7  13:10:00
# 300333          R    920  0.62  2019-07-23 05:58:47               7  13:10:00
# 300334          R    810  0.55  2019-07-23 05:58:47               7  13:10:00
# 300335          Y   1490  1.00  2019-07-23 05:58:47               7  13:10:00
#
#        TODD          DD Month      DOW  US_Price      DOPD          PD MOPD  \
# 0         M  2019-01-04    20   Friday     260.4  Thursday  2019-01-03   01
# 1         M  2019-01-04    20   Friday     229.6  Thursday  2019-01-03   01
# 2         M  2019-01-04    20   Friday     750.4  Thursday  2019-01-03   01
# 3         M  2019-01-04    20   Friday     228.9  Thursday  2019-01-03   01
# 4         M  2019-01-04    20   Friday     229.6  Thursday  2019-01-03   01
# ...     ...         ...   ...      ...       ...       ...         ...  ...
# 300331    A  2019-07-30    20  Tuesday     116.2   Tuesday  2019-07-23   07
# 300332    A  2019-07-30    20  Tuesday     123.2   Tuesday  2019-07-23   07
# 300333    A  2019-07-30    20  Tuesday     128.8   Tuesday  2019-07-23   07
# 300334    A  2019-07-30    20  Tuesday     113.4   Tuesday  2019-07-23   07
# 300335    A  2019-07-30    20  Tuesday     208.6   Tuesday  2019-07-23   07
#
#             TOPD TOPD_L
# 0       14:26:00      A
# 1       14:26:00      A
# 2       14:26:00      A
# 3       14:26:00      A
# 4       14:26:00      A
# ...          ...    ...
# 300331  05:58:00    nan
# 300332  05:58:00    nan
# 300333  05:58:00    nan
# 300334  05:58:00    nan
# 300335  05:58:00    nan
#
# [300336 rows x 22 columns]

# %%
df1 = pd.read_csv('sha-pek.csv')

# %% [markdown]
# ## Second Data set

# %%
df1
# Out:
#               ID flightNumber craftTypeCode depAirport traAirport arrAirport  \
# 0       78246995       CA1550           77W        SHA        NaN        PEK
# 1       78246997       CA1550           77W        SHA        NaN        PEK
# 2       78246998       CA1550           77W        SHA        NaN        PEK
# 3       78246999       CA1550           77W        SHA        NaN        PEK
# 4       78247002       MU5125           33L        SHA        NaN        PEK
# ...          ...          ...           ...        ...        ...        ...
# 268576  77617774       MU5389           325        SHA        LYA        PEK
# 268577  77617775       MU5389           325        SHA        LYA        PEK
# 268578  77617776       MU5389           325        SHA        LYA        PEK
# 268579  77617777       MU5389           325        SHA        LYA        PEK
# 268580  77617779       MU5389           325        SHA        LYA        PEK
#
#               departureDate          arrivalDate cabinClass priceClass  price  \
# 0       2019-07-16 19:55:00  2019-07-16 22:10:00          C          Z   2980
# 1       2019-07-16 19:55:00  2019-07-16 22:10:00          C          J   5810
# 2       2019-07-16 19:55:00  2019-07-16 22:10:00          C          D   3730
# 3       2019-07-16 19:55:00  2019-07-16 22:10:00          C          C   4170
# 4       2019-07-16 20:05:00  2019-07-16 22:10:00          C          I   2000
# ...                     ...                  ...        ...        ...    ...
# 268576  2019-07-21 07:20:00  2019-07-21 12:00:00          Y          R    830
# 268577  2019-07-21 07:20:00  2019-07-21 12:00:00          Y          R    880
# 268578  2019-07-21 07:20:00  2019-07-21 12:00:00          Y          R    920
# 268579  2019-07-21 07:20:00  2019-07-21 12:00:00          Y          R    790
# 268580  2019-07-21 07:20:00  2019-07-21 12:00:00          Y          Y   1490
#
#         rate           createDate  dateDifference
# 0       0.52  2019-07-17 02:32:27              -1
# 1       1.00  2019-07-17 02:32:27              -1
# 2       0.65  2019-07-17 02:32:27              -1
# 3       0.72  2019-07-17 02:32:27              -1
# 4       0.36  2019-07-17 02:32:27              -1
# ...      ...                  ...             ...
# 268576  0.56  2019-07-14 23:28:01               7
# 268577  0.60  2019-07-14 23:28:01               7
# 268578  0.62  2019-07-14 23:28:01               7
# 268579  0.54  2019-07-14 23:28:01               7
# 268580  1.00  2019-07-14 23:28:01               7
#
# [268581 rows x 14 columns]

# %%
df1.traAirport.fillna(0, inplace = True)

# %%
df.traAirport.replace('LYA',1, inplace = True)

# %%
df1['TOD']= [x[11:16] for x in df1.departureDate]

# %%
df1['TOD'] = pd.to_datetime(df1['TOD'])

# %%
df1['TOD'] = [time.time() for time in df1['TOD']]

# %%
df1['DD'] = [x[:10]for x in df1['departureDate']]

# %%
df1['DOW'] = [findDay(x) for x in df1['DD']]

# %%
df1['TODD']= np.where(((df1['TOD']> datetime.time(6,0)) & (df1['TOD']<= datetime.time(12,0))), 'M', np.nan)

# %%
df1['TODD'] = np.where(((df1['TOD']> datetime.time(12,0)) & (df1['TOD']<= datetime.time(18,0))), 'A', df1['TODD'])

# %%
df1['TODD'] = np.where(((df1['TOD']> datetime.time(18,0)) & (df1['TOD']<= datetime.time(23,0))), 'N', df1['TODD'])

# %%
df1['US_Price'] = [x * 0.14 for x in df1['price']]

# %%
df1['DOPD'] = [x[:10] for x in df1['createDate']]

# %%
df1['PD'] = [x[:10] for x in df1['createDate']]

# %%
df1['DOPD'] = [findDay(x) for x in df1['DOPD']]

# %%
df1['MOPD'] = [x[5:7] for x in df1['PD']]

# %%
df1['TOPD'] = [x[11:16] for x in df1['createDate']]

# %%
df1['TOPD'] = pd.to_datetime(df1['TOPD'])

# %%
df1['TOPD'] = [time.time() for time in df1['TOPD']]

# %%
df1['TOPD_L']= np.where(((df1['TOPD']> datetime.time(6,0)) & (df1['TOPD']<= datetime.time(12,0))), 'M', np.nan)
df1['TOPD_L'] = np.where(((df1['TOPD']> datetime.time(12,0)) & (df1['TOPD']<= datetime.time(18,0))), 'A', df1['TOPD_L'])
df1['TOPD_L'] = np.where(((df1['TOPD']> datetime.time(18,0)) & (df1['TOPD']<= datetime.time(23,0))), 'N', df1['TOPD_L'])

# %%
df1
# Out:
#               ID flightNumber craftTypeCode depAirport traAirport arrAirport  \
# 0       78246995       CA1550           77W        SHA          0        PEK
# 1       78246997       CA1550           77W        SHA          0        PEK
# 2       78246998       CA1550           77W        SHA          0        PEK
# 3       78246999       CA1550           77W        SHA          0        PEK
# 4       78247002       MU5125           33L        SHA          0        PEK
# ...          ...          ...           ...        ...        ...        ...
# 268576  77617774       MU5389           325        SHA        LYA        PEK
# 268577  77617775       MU5389           325        SHA        LYA        PEK
# 268578  77617776       MU5389           325        SHA        LYA        PEK
# 268579  77617777       MU5389           325        SHA        LYA        PEK
# 268580  77617779       MU5389           325        SHA        LYA        PEK
#
#               departureDate          arrivalDate cabinClass priceClass  price  \
# 0       2019-07-16 19:55:00  2019-07-16 22:10:00          C          Z   2980
# 1       2019-07-16 19:55:00  2019-07-16 22:10:00          C          J   5810
# 2       2019-07-16 19:55:00  2019-07-16 22:10:00          C          D   3730
# 3       2019-07-16 19:55:00  2019-07-16 22:10:00          C          C   4170
# 4       2019-07-16 20:05:00  2019-07-16 22:10:00          C          I   2000
# ...                     ...                  ...        ...        ...    ...
# 268576  2019-07-21 07:20:00  2019-07-21 12:00:00          Y          R    830
# 268577  2019-07-21 07:20:00  2019-07-21 12:00:00          Y          R    880
# 268578  2019-07-21 07:20:00  2019-07-21 12:00:00          Y          R    920
# 268579  2019-07-21 07:20:00  2019-07-21 12:00:00          Y          R    790
# 268580  2019-07-21 07:20:00  2019-07-21 12:00:00          Y          Y   1490
#
#         rate           createDate  dateDifference       TOD TODD  US_Price  \
# 0       0.52  2019-07-17 02:32:27              -1  19:55:00    N     417.2
# 1       1.00  2019-07-17 02:32:27              -1  19:55:00    N     813.4
# 2       0.65  2019-07-17 02:32:27              -1  19:55:00    N     522.2
# 3       0.72  2019-07-17 02:32:27              -1  19:55:00    N     583.8
# 4       0.36  2019-07-17 02:32:27              -1  20:05:00    N     280.0
# ...      ...                  ...             ...       ...  ...       ...
# 268576  0.56  2019-07-14 23:28:01               7  07:20:00    M     116.2
# 268577  0.60  2019-07-14 23:28:01               7  07:20:00    M     123.2
# 268578  0.62  2019-07-14 23:28:01               7  07:20:00    M     128.8
# 268579  0.54  2019-07-14 23:28:01               7  07:20:00    M     110.6
# 268580  1.00  2019-07-14 23:28:01               7  07:20:00    M     208.6
#
#              DOPD          PD MOPD      TOPD TOPD_L          DD      DOW
# 0       Wednesday  2019-07-17   07  02:32:00    nan  2019-07-16  Tuesday
# 1       Wednesday  2019-07-17   07  02:32:00    nan  2019-07-16  Tuesday
# 2       Wednesday  2019-07-17   07  02:32:00    nan  2019-07-16  Tuesday
# 3       Wednesday  2019-07-17   07  02:32:00    nan  2019-07-16  Tuesday
# 4       Wednesday  2019-07-17   07  02:32:00    nan  2019-07-16  Tuesday
# ...           ...         ...  ...       ...    ...         ...      ...
# 268576     Sunday  2019-07-14   07  23:28:00    nan  2019-07-21   Sunday
# 268577     Sunday  2019-07-14   07  23:28:00    nan  2019-07-21   Sunday
# 268578     Sunday  2019-07-14   07  23:28:00    nan  2019-07-21   Sunday
# 268579     Sunday  2019-07-14   07  23:28:00    nan  2019-07-21   Sunday
# 268580     Sunday  2019-07-14   07  23:28:00    nan  2019-07-21   Sunday
#
# [268581 rows x 24 columns]

# %%
df1['TOD'] = [time.time() for time in df1['TOD']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-c259fbf397c0> in <module>
# ----> 1 df1['TOD'] = [time.time() for time in df1['TOD']]
#
# <ipython-input-44-c259fbf397c0> in <listcomp>(.0)
# ----> 1 df1['TOD'] = [time.time() for time in df1['TOD']]
#
# AttributeError: 'datetime.time' object has no attribute 'time'

# %% [markdown]
# #
