# %%
# !pip install mysql-connector-python

# %%
import json
import mysql.connector
from mysql.connector import errorcode
from datetime import date, datetime, timedelta
import requests
# import config

# %%
api_key = '-l3rKHolVYw-h0abF8OGqbAHrsoDHWN1DD0IN3d9FfBT7U0I7CPVqLwbQHRgLCuywXYDO7OXxvDe8DZuiqsjEuANbXL8ddVThTtZ-ZQULsvvZ1N4sZAV-3T3CvQpXnYx'

# %%
cnx = mysql.connector.connect(
    host = 'database-1.c3cnzogwpqkc.us-east-2.rds.amazonaws.com',
    user = 'admin',
    passwd = 'Psbz67j00',
    port = 3306
    
)
cursor = cnx.cursor()

# %%
cursor

# %%
def yelp_call():
    
    client_id = 'IvYmsjR9a7mY_srfvE8d1'
    
    api_key = '-l3rKHolVYw-h0abF8OGqbAHrsoDHWN1DD0IN3d9FfBT7U0I7CPVqLwbQHRgLCuywXYDO7OXxvDe8DZuiqsjEuANbXL8ddVThTtZ-ZQULsvvZ1N4sZAV-3T3CvQpXnYx'
    term = 'Greek'
    location = 'Astoria NY'
    SEARCH_LIMIT = 10
    
    url_params = {'term': term.replace(' ', '+'), 'location': location.replace(' ', '+'), 'limit': SEARCH_LIMIT}
    
    url = 'https://api.yelp.com/v3/businesses/search'
    
    headers = {'Authorization': 'Bearer {}'.format(api_key)}
    
    response = requests.get(url, headers=headers, params=url_params)
    
    return response

# %%
Yelp_data = yelp_call()#confirm key type is json format

# %%
My_data=Yelp_data.json()

# %%
My_data
# Out:
# {'businesses': [{'id': 'JEQ00qBAepe0oSiUBdfIew',
#    'alias': 'taverna-kyclades-astoria',
#    'name': 'Taverna Kyclades',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xdDX0-2haobds2dlMgUmYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taverna-kyclades-astoria?adjust_creative=IvYmsjR9a7mY_srfvE8d1w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=IvYmsjR9a7mY_srfvE8d1w',
#    'review_count': 2242,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7753227, 'longitude': -73.909217},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3307 Ditmars Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
# ...

# %%
for key in response.json().keys():
    print(key)
    value = response.json()[key] #Use standard dictionary formatting
    print(type(value)) #What type is it?
    print('\n\n')

# %%
yelp_data =response.json()
yelp_data['businesses'][:2]
type(yelp_data)

# %%
My_data

# %%
def parse_results(results):
    id_list = []
    alias_list = []
    name_list = []
    review_count_list = []
    rating_list = []
    price_list = []
    for i in range(len(obj['businesses'])):
        if 'id' in obj['businesses'][i].keys():
            id_list.append(obj['businesses'][i]['id'])
        else:
            id_list.append('n/a')
        if 'alias' in obj['businesses'][i].keys():
            alias_list.append(obj['businesses'][i]['alias'])
        else:
            alias_list.append('n/a')
        if 'name' in obj['businesses'][i].keys():
            name_list.append(obj['businesses'][i]['name'])
        else:
            name_list.append('n/a')
        if 'review_count' in obj['businesses'][i].keys():
            review_count_list.append(obj['businesses'][i]['review_count'])
        else:
            review_count_list.append('n/a')
        if 'rating' in obj['businesses'][i].keys():
            rating_list.append(obj['businesses'][i]['rating'])
        else:
            rating_list.append('n/a')
        if 'price' in obj['businesses'][i].keys():
            price_list.append(len(obj['businesses'][i]['price']))
        else:
            price_list.append('n/a')
    parsed_results = pd.DataFrame(list(zip(id_list, alias_list, name_list, review_count_list, rating_list, price_list)), columns = ['id_list', 'alias_list', 'name_list', 'review_count_list', 'rating_list', 'price_list'])
    return parsed_results

# %%
ye

# %%
cnx = mysql.connector.connect(
    host = 'database-1.c3cnzogwpqkc.us-east-2.rds.amazonaws.com',
    user = 'admin',
    passwd = 'Psbz67j00',
    port = 3306
    database = Yelp_base
)
cursor = cnx.cursor()

# %%
type(cursor)

# %%
def create_database(cursor, database):
    try:
        cursor.execute(
            "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(database))
    except mysql.connector.Error as err:
        print("Failed creating database: {}".format(err))
        exit(1)

# %%
try:
    cursor.execute("USE {}".format(db_name))

#if the previous line fails because there isn't a db by that name run this line

except mysql.connector.Error as err:
    print("Database {} does not exists.".format(db_name))
    if err.errno == errorcode.ER_BAD_DB_ERROR:
        create_database(cursor, db_name)
        print("Database {} created successfully.".format(db_name))
        cnx.database = db_name
    else:
        print(err)
        exit(1)
